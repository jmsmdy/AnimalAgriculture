# %% [markdown]
# ## This code takes intermediate CSVs transcribed from PDFs and puts it in a consistent format

# %%
import pandas as pd

# Loading CSVs parsed from PDF through Tabula and manually fixed
years = [2015, 2016, 2017, 2018]
csvs = {year : f'Intermediate CSVs/tabula-cases-by-county-{year}.csv' for year in years}
dfs = {year : pd.read_csv(csvs[year]) for year in csvs.keys()}

# Tranpose tables and clean up whitespace
for year in years:
    dfs[year] = dfs[year].T
    dfs[year].columns = dfs[year].iloc[0].apply(lambda x: x.strip())
    dfs[year].drop(dfs[year].index[0], inplace=True)

# %%
# Checking that county totals add up to "Arizona" column
for year in years:
    print(year, dfs[year].loc['Arizona'] - dfs[year].drop(dfs[year].index[0]).sum())
# Out:
# 2015 Disease
# Measles                                                            0
# Mumps                                                              0
# Pertussis                                                          0
# Pertussis confirmed cases                                          0
# Rubella                                                            0
# Congenital Rubella Syndrome                                        0
# Haemophilus influenzae  type B (invasive, age < 5 years)           0
# Varicella (chickenpox)                                             0
# Aseptic Meningitis                                                 0
# Meningococcal Disease                                              0
# Viral Encephalitis                                                 0
# Amebiasis                                                          0
# Campylobacteriosis                                                 0
# Cholera                                                            0
# Cryptosporidiosis                                                  0
# E. coli, Shiga toxin-producing                                     0
# Giardiasis                                                         0
# Salmonellosis (except S. Typhi and S. Paratyphi)                   0
# Salmonella Paratyphi A                                             0
# Salmonella Paratyphi B                                             0
# Salmonella Paratyphi C                                             0
# Shigellosis                                                        0
# Typhoid Fever                                                      0
# Coccidioidomycosis (Valley Fever)                                  0
# Hepatitis A                                                        0
# Hepatitis B, Acute                                                 0
# Hepatitis B, Perinatal                                             0
# Hepatitis D                                                        0
# Hepatitis E                                                        0
# Brucellosis                                                        0
# Colorado Tick Fever                                                0
# Dengue                                                             0
# Ehrlichiosis/Anaplasmosis                                          0
# Hantavirus Pulmonary Syndrome                                      0
# Human Rabies                                                       0
# Lyme Disease                                                       0
# Malaria                                                            0
# Plague                                                             0
# Relapsing Fever, Tickborne                                         0
# Rocky Mtn. Spotted Fever                                           0
# St. Louis Encephalitis                                             0
# Tularemia                                                          0
# West Nile Virus                                                    0
# Botulism                                                           0
# Legionellosis                                                      0
# Listeriosis                                                        0
# Methicillin Resistant S. aureus (invasive)                         0
# Streptococcal Group A (invasive)                                   0
# Streptococcal Group B (invasive disease in infants<90 days old)    0
# Streptococcus pneumoniae  (invasive)                               0
# Reyes Syndrome                                                     0
# Toxic Shock Syndrome                                               0
# Vibrio  spp. (except toxogenic V. cholerae )                       0
# dtype: object
# 2016 Disease
# Measles                                                            0
# Mumps                                                              0
# Pertussis                                                          0
# Pertussis confirmed cases                                          0
# Rubella                                                            0
# Congenital Rubella Syndrome                                        0
# Haemophilus influenzae  type B (invasive, age < 5 years)           0
# Varicella (chickenpox)                                             0
# Aseptic Meningitis                                                 0
# Meningococcal Disease                                              0
# Viral Encephalitis                                                 0
# Amebiasis                                                          0
# Campylobacteriosis                                                 0
# Cholera                                                            0
# Streptococcal Group B (invasive disease in infants<90 days old)    0
# Streptococcus pneumoniae  (invasive)                               0
# Reyes Syndrome                                                     0
# Toxic Shock Syndrome                                               0
# Vibrio  spp. (except toxogenic V. cholerae )                       0
# dtype: object
# 2018 Disease
# Measles                                                            0
# Mumps                                                              0
# Pertussis                                                          0
# Pertussis confirmed cases                                          0
# Rubella                                                            0
# Congenital Rubella Syndrome                                        0
# Haemophilus influenzae  type B (invasive, age < 5 years)           0
# Varicella (chickenpox)                                             0
# Meningococcal Disease                                              0
# Viral Encephalitis                                                 0
# Amebiasis                                                          0
# Campylobacteriosis                                                 0
# Cholera                                                            0
# Cryptosporidiosis                                                  0
# E. coli, Shiga toxin-producing                                     0
# Giardiasis                                                         0
# Salmonellosis (except S. Typhi and S. Paratyphi)                   0
# Salmonella Paratyphi A                                             0
# Salmonella Paratyphi B                                             0
# Salmonella Paratyphi C                                             0
# Shigellosis                                                        0
# Typhoid Fever                                                      0
# Coccidioidomycosis (Valley Fever)                                  0
# Hepatitis A                                                        0
# Hepatitis B, Acute                                                 0
# Hepatitis B, Perinatal                                             0
# Hepatitis D                                                        0
# Hepatitis E                                                        0
# Brucellosis                                                        0
# Colorado Tick Fever                                                0
# Dengue                                                             0
# Ehrlichiosis/Anaplasmosis                                          0
# Hantavirus Pulmonary Syndrome                                      0
# Human Rabies                                                       0
# Lyme Disease                                                       0
# Malaria                                                            0
# Plague                                                             0
# Relapsing Fever, Tickborne                                         0
# Rocky Mtn. Spotted Fever                                           0
# St. Louis Encephalitis                                             0
# Tularemia                                                          0
# West Nile Virus                                                    0
# Botulism                                                           0
# Legionellosis                                                      0
# Listeriosis                                                        0
# Methicillin-Resistant S. aureus (invasive)                         0
# Streptococcal Group A (invasive)                                   0
# Streptococcal Group B (invasive disease in infants<90 days old)    0
# Streptococcus pneumoniae  (invasive)                               0
# Toxic Shock Syndrome                                               0
# Vibrio  spp. (except toxogenic V. cholerae )                       0
# Yersiniosis (except Y. pestis)                                     0
# dtype: object

# %% [markdown]
# The statewide total for Mumps in 2017 is off by one, an error in the original data set. We'll ignore this error and drop statewide totals.

# %%
for year in years:
    dfs[year] = dfs[year].drop(dfs[year].index[0])

# %% [markdown]
# Now let's produce output CSVs for the diseases we are tracking across multiple states.

# %%
diseases = {'STEC' : 'E. coli, Shiga toxin-producing',
            'Campylobacteriosis' : 'Campylobacteriosis',
            'Salmonellosis' : 'Salmonellosis (except S. Typhi and S. Paratyphi)'}

output_dfs = {}
for disease, column_name in diseases.items():
    output_dfs[disease] = pd.concat([
        pd.concat([dfs[year][column_name] for year in years], axis=1),
        pd.concat([dfs[year][column_name].apply(lambda x: '-') for year in years], axis=1)
    ], axis=1)
    output_dfs[disease].columns = [f'{year} COUNT' for year in years] +  [f'{year} RATE' for year in years]
    output_dfs[disease].index.name ='COUNTY'

# %%
for disease in diseases:
    output_dfs[disease].to_csv(f'AZ_{disease}.csv')
